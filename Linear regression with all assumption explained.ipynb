# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv(r"D:\Data\26-Weeks-Of-Data-Science-masters\26-Weeks-Of-Data-Science-master\Week-08-Linear_Regression\data\Advertising.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
plt.scatter(data['TV'],data['sales'])
plt.title("TV v/s sales")
plt.xlabel('TV')
plt.ylabel('sales')
plt.show()
#There is a positive relation between the sales and the TV,which means as the TV advertisement will 
#increase the sales will also ve increased

# %%
plt.scatter(data['radio'],data['sales'])
plt.title("radio v/s sales")
plt.axvline(x=40,linewidth=1,color='r')
plt.xlabel("radio")
plt.ylabel("sales")
plt.show()
#There is some relationship between these two variables

# %%
plt.scatter(data['TV'],data['sales'])
plt.title("TV v/s sales")
plt.xlabel("TV")
plt.ylabel("sales")
plt.show()
plt.show()

# %%
X=data.iloc[:,1:4]
Y=data.iloc[:,4]

# %%
LR=LinearRegression()
LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
LR.score(X,Y)
# Out:
# 0.8972106381789521

# %%
print(LR.intercept_)
print(LR.coef_)
# Out:
# 2.9388893694594085
# [ 0.04576465  0.18853002 -0.00103749]

# %%
Y_predict=LR.predict(X)

# %%
Y_predict
# Out:
# array([20.52397441, 12.33785482, 12.30767078, 17.59782951, 13.18867186,
#        12.47834763, 11.72975995, 12.12295317,  3.72734086, 12.55084872,
#         7.0322992 , 17.28512918, 10.57712073,  8.82630048, 18.43436638,
#        20.81929952, 12.82365674, 23.22495716,  9.95168206, 14.16607293,
#        18.10076728, 14.7405382 ,  6.4891503 , 16.5459329 ,  8.14651887,
#        15.6100386 , 14.98951429, 17.05167344, 19.41053803,  9.14402389,
#        21.6339338 , 11.3460929 ,  7.63888314, 18.86426829,  7.57483051,
#        17.00682618, 23.40590052, 15.62347779,  9.90868103, 20.44761039,
#        16.37766467, 17.2959832 , 21.59580326, 13.96385684,  8.88787996,
#        15.16152314,  8.87338673, 21.7226299 , 16.26362018,  8.1681656 ,
#        12.63121132,  9.33981296, 20.66297563, 19.94469957, 20.37443008,
#        21.2926106 ,  8.52771254, 12.77458802, 21.89805198, 18.13348698,
#         5.74215558, 22.89067208, 16.78426073, 13.21069202, 16.97773556,
# ...

# %%
            20.52397441, 12.33785482, 12.30767078, 17.59782951, 13.18867186

# %%
    data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(Y_predict,Y)
# Out:
# 2.7841263145109365

# %%
TV	radio	newspaper
# Out:
#   File "<ipython-input-31-b482fc4916b7>", line 1
#     TV	radio	newspaper
#       	^
# SyntaxError: invalid syntax

# %%
sales=2.93+0.04576465*230.1+0.18853002*37.8+-0.00103749*69.2
sales
# Out:
# 20.515086412999995

# %% [markdown]
# # Assumption of Linear Regression

# %% [markdown]
# #1.There should be linear relationship between dependent and indpendent variable

# %%
plt.scatter(data['TV'],data['sales'])

# %% [markdown]
# #2There is no multicollinearity between independent variable,there is no dependency between variable and it can be detected using variable inflation factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

# %%
vif_data
# Out:
#      feature
# 0         TV
# 1      radio
# 2  newspaper

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)

#vif value is not higher then 5 so no multicollinearity
# Out:
#      feature       VIF
# 0         TV  2.486772
# 1      radio  3.285462
# 2  newspaper  3.055245

# %%
#Even using pairplot multicollearity can be observed
import seaborn as sns
sns.pairplot(X)
import numpy as np

# %%
residuals = Y.values-Y_predict
residuals
# Out:
# array([ 1.57602559e+00, -1.93785482e+00, -3.00767078e+00,  9.02170488e-01,
#        -2.88671857e-01, -5.27834763e+00,  7.02400484e-02,  1.07704683e+00,
#         1.07265914e+00, -1.95084872e+00,  1.56770080e+00,  1.14870817e-01,
#        -1.37712073e+00,  8.73699520e-01,  5.65633616e-01,  1.58070048e+00,
#        -3.23656744e-01,  1.17504284e+00,  1.34831794e+00,  4.33927068e-01,
#        -1.00767277e-01, -2.24053820e+00, -8.89150304e-01, -1.04593290e+00,
#         1.55348113e+00, -3.61003860e+00,  1.04857116e-02, -1.15167344e+00,
#        -5.10538027e-01,  1.35597611e+00, -2.33933803e-01,  5.53907096e-01,
#         1.96111686e+00, -1.46426829e+00,  1.92516949e+00, -4.20682618e+00,
#         1.99409948e+00, -9.23477789e-01,  1.91318965e-01,  1.05238961e+00,
#         2.22335329e-01, -1.95983199e-01, -8.95803256e-01, -1.06385684e+00,
#        -3.87879956e-01, -2.61523139e-01,  1.72661327e+00,  1.47737010e+00,
# ...

# %%
#3 Homoscedasticity Assumption:This situation arises when error term is constant even if there is a change in predictor
p = sns.scatterplot(Y_predict,residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot([0,26],[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')
# Out:
# C:\Users\bhave1994\anaconda3\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\bhave1994\anaconda3\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Null hypothesis:Error term are homoskedestacity
#Alternate:Heteroskedestic

import statsmodels.stats.api as sms
from statsmodels.compat import lzip
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residuals, X)
lzip(name, test)
#P value is greater than 0.05 so we cannot reject null hypothesis,hence error terms are homoskedacity
# Out:
# [('F statistic', 1.3444110321318343), ('p-value', 0.07338571632410348)]

# %%
#bartlett test

# %%
#test = bartlett(X,residuals)
#print(test)

# %% [markdown]
# #No autocorrelation in residuals(used in timeseries model)
# #Error terms are not correlated that means one observation does not have impact on other observation
# *Durbin Watson test is used to check for autocorrelation
# Null Hypothesis Ho : There is no autocorrelation of errors
# Alternate Hypothesis Ha : There is autocorrelation of errors
# -A value between 1.8 and 2.2 indicates no autocorrelation. A value less than 1.8 indicates positive autocorrelation and a value   greater than 2.2 indicates negative autocorrelation

# %%
import statsmodels.api as sm

X_constant = sm.add_constant(X)
lin_reg = sm.OLS(Y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Fri, 21 Jan 2022   Prob (F-statistic):           1.58e-96
# Time:                        19:51:24   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
resids = lin_reg.resid

# %%
from scipy import stats

def normality_of_residuals_test(model):
    '''
    Function for drawing the normal QQ-plot of the residuals and running 4 statistical tests to 
    investigate the normality of residuals.
    
    Arg:
    * model - fitted OLS models from statsmodels
    '''
    sm.ProbPlot(model.resid).qqplot(line='s');
    plt.title('Q-Q plot');

    jb = stats.jarque_bera(model.resid)
    sw = stats.shapiro(model.resid)
    ad = stats.anderson(model.resid, dist='norm')
    ks = stats.kstest(model.resid, 'norm')
    
    print(f'Jarque-Bera test ---- statistic: {jb[0]:.4f}, p-value: {jb[1]}')
    print(f'Shapiro-Wilk test ---- statistic: {sw[0]:.4f}, p-value: {sw[1]:.4f}')
    print(f'Kolmogorov-Smirnov test ---- statistic: {ks.statistic:.4f}, p-value: {ks.pvalue:.4f}')
    print(f'Anderson-Darling test ---- statistic: {ad.statistic:.4f}, 5% critical value: {ad.critical_values[2]:.4f}')
    print('If the returned AD statistic is larger than the critical value, then for the 5% significance level, the null hypothesis that the data come from the Normal distribution should be rejected. ')
    
normality_of_residuals_test(lin_reg)
# Out:
# Jarque-Bera test ---- statistic: 151.2414, p-value: 0.0
# Shapiro-Wilk test ---- statistic: 0.9177, p-value: 0.0000
# Kolmogorov-Smirnov test ---- statistic: 0.1626, p-value: 0.0000
# Anderson-Darling test ---- statistic: 3.7020, 5% critical value: 0.7720
# If the returned AD statistic is larger than the critical value, then for the 5% significance level, the null hypothesis that the data come from the Normal distribution should be rejected.

# %%
sm.ProbPlot(lin_reg.resid).qqplot(line='s')
